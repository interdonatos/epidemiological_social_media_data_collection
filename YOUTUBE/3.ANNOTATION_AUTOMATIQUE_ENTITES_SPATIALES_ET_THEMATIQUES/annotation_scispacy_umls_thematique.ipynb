# %%
# !pip install spacy
# !pip install scispacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.10.0.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Collecting scispacy
#   Downloading scispacy-0.4.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 2.2 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from scispacy) (1.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scispacy) (1.19.5)
# Collecting conllu
#   Downloading conllu-4.4.1-py2.py3-none-any.whl (15 kB)
# Collecting pysbd
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 3.2 MB/s
# Collecting spacy<3.1.0,>=3.0.0
#   Downloading spacy-3.0.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 11.4 MB/s
# Collecting nmslib>=1.7.3.6
#   Downloading nmslib-2.1.1-cp37-cp37m-manylinux2010_x86_64.whl (13.5 MB)
#      |████████████████████████████████| 13.5 MB 45.8 MB/s
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.7/dist-packages (from scispacy) (1.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scispacy) (2.23.0)
# Collecting pybind11<2.6.2
#   Downloading pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
#      |████████████████████████████████| 188 kB 63.7 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy) (5.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.3->scispacy) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.3->scispacy) (1.4.1)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy) (3.10.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy) (21.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy) (0.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy) (0.4.1)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 59.3 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy) (1.0.6)
# Collecting thinc<8.1.0,>=8.0.3
#   Downloading thinc-8.0.13-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (628 kB)
#      |████████████████████████████████| 628 kB 42.2 MB/s
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (451 kB)
#      |████████████████████████████████| 451 kB 42.4 MB/s
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy) (3.0.6)
# Collecting spacy-legacy<3.1.0,>=3.0.5
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.6 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy) (4.62.3)
# Collecting catalogue<2.1.0,>=2.0.4
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.1.0,>=3.0.0->scispacy) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->scispacy) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->scispacy) (5.2.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->scispacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->scispacy) (2.0.1)
# Installing collected packages: catalogue, typer, srsly, pydantic, thinc, spacy-legacy, pybind11, pathy, spacy, pysbd, nmslib, conllu, scispacy
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed catalogue-2.0.6 conllu-4.4.1 nmslib-2.1.1 pathy-0.6.1 pybind11-2.6.1 pydantic-1.8.2 pysbd-0.3.4 scispacy-0.4.0 spacy-3.0.7 spacy-legacy-3.0.8 srsly-2.4.2 thinc-8.0.13 typer-0.3.2

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_md-0.4.0.tar.gz
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_md-0.4.0.tar.gz
#   Downloading https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_md-0.4.0.tar.gz (125.2 MB)
#      |████████████████████████████████| 125.2 MB 64 kB/s
# Requirement already satisfied: spacy<3.1.0,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from en-core-sci-md==0.4.0) (3.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (4.62.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (3.10.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (2.4.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (21.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (1.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (2.23.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (0.4.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (0.6.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (8.0.13)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (1.0.6)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (0.3.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (0.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (2.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (3.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (3.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (2021.10.8)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.1.0,>=3.0.1->en-core-sci-md==0.4.0) (2.0.1)
# Building wheels for collected packages: en-core-sci-md
#   Building wheel for en-core-sci-md (setup.py) ... done
#   Created wheel for en-core-sci-md: filename=en_core_sci_md-0.4.0-py3-none-any.whl size=125733930 sha256=887d59b9193daa1cba2890e1c492d02fc018caaba148ff09b7bfe2cb2641c46c
#   Stored in directory: /root/.cache/pip/wheels/43/54/a8/27fc51c81ba9feda7ba7f9031eb81e33429840cd79d141c88c
# Successfully built en-core-sci-md
# Installing collected packages: en-core-sci-md
# Successfully installed en-core-sci-md-0.4.0

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_ner_bc5cdr_md-0.4.0.tar.gz
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_ner_bc5cdr_md-0.4.0.tar.gz
#   Downloading https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_ner_bc5cdr_md-0.4.0.tar.gz (125.1 MB)
#      |████████████████████████████████| 125.1 MB 29 kB/s
# Requirement already satisfied: spacy<3.1.0,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from en-ner-bc5cdr-md==0.4.0) (3.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (1.8.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (3.10.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (2.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (8.0.13)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (2.23.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (0.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (4.62.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (3.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (2.4.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (0.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (21.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (1.0.6)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (0.6.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (1.19.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.1.0,>=3.0.1->en-ner-bc5cdr-md==0.4.0) (2.0.1)
# Building wheels for collected packages: en-ner-bc5cdr-md
#   Building wheel for en-ner-bc5cdr-md (setup.py) ... done
#   Created wheel for en-ner-bc5cdr-md: filename=en_ner_bc5cdr_md-0.4.0-py3-none-any.whl size=125666882 sha256=375dd23c4cd7e405a8d94fe8812c4bce1cffae54ab86c949785ca92db84da5e9
#   Stored in directory: /root/.cache/pip/wheels/6a/17/04/ed8f50ffdcb9b9e4ce601c0c3cf88361f2b3f54a10c0fa0803
# Successfully built en-ner-bc5cdr-md
# Installing collected packages: en-ner-bc5cdr-md
# Successfully installed en-ner-bc5cdr-md-0.4.0

# %%
# !pip install spacy-transformers
# Out:
# Collecting spacy-transformers
#   Downloading spacy_transformers-1.1.2-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 145 kB/s
# Collecting spacy<4.0.0,>=3.1.3
#   Downloading spacy-3.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 8.7 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers) (1.10.0+cu111)
# Collecting transformers<4.12.0,>=3.4.0
#   Downloading transformers-4.11.3-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 50.1 MB/s
# Collecting spacy-alignments<1.0.0,>=0.7.2
#   Downloading spacy_alignments-0.8.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 18.9 MB/s
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers) (2.4.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (3.10.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (4.62.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.11.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.4.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (8.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.6)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 64.7 MB/s
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.23.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.3.2)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.19.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<4.0.0,>=3.1.3->spacy-transformers) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<4.0.0,>=3.1.3->spacy-transformers) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (1.24.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.12.0,>=3.4.0->spacy-transformers) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<4.12.0,>=3.4.0->spacy-transformers) (4.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<4.12.0,>=3.4.0->spacy-transformers) (3.4.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 69.1 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 33.3 MB/s
# Collecting huggingface-hub>=0.0.17
#   Downloading huggingface_hub-0.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.9 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 71.8 MB/s
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<4.0.0,>=3.1.3->spacy-transformers) (2.0.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.12.0,>=3.4.0->spacy-transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.12.0,>=3.4.0->spacy-transformers) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, spacy-loggers, sacremoses, langcodes, huggingface-hub, transformers, spacy-alignments, spacy, spacy-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.0.7
#     Uninstalling spacy-3.0.7:
#       Successfully uninstalled spacy-3.0.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scispacy 0.4.0 requires spacy<3.1.0,>=3.0.0, but you have spacy 3.2.0 which is incompatible.
# en-ner-bc5cdr-md 0.4.0 requires spacy<3.1.0,>=3.0.1, but you have spacy 3.2.0 which is incompatible.
# en-core-sci-md 0.4.0 requires spacy<3.1.0,>=3.0.1, but you have spacy 3.2.0 which is incompatible.
# Successfully installed huggingface-hub-0.1.2 langcodes-3.3.0 pyyaml-6.0 sacremoses-0.0.46 spacy-3.2.0 spacy-alignments-0.8.4 spacy-loggers-1.0.1 spacy-transformers-1.1.2 tokenizers-0.10.3 transformers-4.11.3

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_scibert-0.4.0.tar.gz
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_scibert-0.4.0.tar.gz
#   Downloading https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_scibert-0.4.0.tar.gz (423.3 MB)
#      |████████████████████████████████| 423.3 MB 16 kB/s
# Collecting spacy<3.1.0,>=3.0.3
#   Using cached spacy-3.0.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.3 MB)
# Requirement already satisfied: spacy-transformers in /usr/local/lib/python3.7/dist-packages (from en-core-sci-scibert==0.4.0) (1.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (2.11.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (2.4.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (0.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (1.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (3.0.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (8.0.13)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (3.10.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (2.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (3.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (1.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (1.19.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (0.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (2.23.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (4.62.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (0.6.1)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (0.3.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (1.24.3)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.1.0,>=3.0.3->en-core-sci-scibert==0.4.0) (2.0.1)
# Collecting spacy-transformers
#   Downloading spacy_transformers-1.1.1-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 2.9 MB/s
#   Downloading spacy_transformers-1.1.0-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.1 MB/s
#   Downloading spacy_transformers-1.0.6-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.2 MB/s
# Collecting transformers<4.10.0,>=3.4.0
#   Downloading transformers-4.9.2-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 10.9 MB/s
# Collecting spacy-transformers
#   Downloading spacy_transformers-1.0.5-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.3 MB/s
#   Downloading spacy_transformers-1.0.4-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.7 MB/s
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers->en-core-sci-scibert==0.4.0) (0.8.4)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers->en-core-sci-scibert==0.4.0) (1.10.0+cu111)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers->en-core-sci-scibert==0.4.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers->en-core-sci-scibert==0.4.0) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers->en-core-sci-scibert==0.4.0) (4.8.2)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers->en-core-sci-scibert==0.4.0) (0.0.46)
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers->en-core-sci-scibert==0.4.0) (3.4.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers->en-core-sci-scibert==0.4.0) (0.10.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.10.0,>=3.4.0->spacy-transformers->en-core-sci-scibert==0.4.0) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.10.0,>=3.4.0->spacy-transformers->en-core-sci-scibert==0.4.0) (1.1.0)
# Building wheels for collected packages: en-core-sci-scibert
#   Building wheel for en-core-sci-scibert (setup.py) ... done
#   Created wheel for en-core-sci-scibert: filename=en_core_sci_scibert-0.4.0-py3-none-any.whl size=423355915 sha256=ada6e285f3bb11d52d77affdceb0141ae8b0aef4f1864fda858310091b64ca2a
#   Stored in directory: /root/.cache/pip/wheels/c2/65/53/10e5a7eb0ba8e2f024e23d9ebc544f2112977afd5ad2690550
# Successfully built en-core-sci-scibert
# Installing collected packages: huggingface-hub, transformers, spacy, spacy-transformers, en-core-sci-scibert
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.1.2
#     Uninstalling huggingface-hub-0.1.2:
#       Successfully uninstalled huggingface-hub-0.1.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.11.3
#     Uninstalling transformers-4.11.3:
#       Successfully uninstalled transformers-4.11.3
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.2.0
#     Uninstalling spacy-3.2.0:
#       Successfully uninstalled spacy-3.2.0
#   Attempting uninstall: spacy-transformers
#     Found existing installation: spacy-transformers 1.1.2
#     Uninstalling spacy-transformers-1.1.2:
#       Successfully uninstalled spacy-transformers-1.1.2
# Successfully installed en-core-sci-scibert-0.4.0 huggingface-hub-0.0.12 spacy-3.0.7 spacy-transformers-1.0.4 transformers-4.9.2

# %%
import scispacy
import spacy
import en_ner_bc5cdr_md
import en_core_sci_scibert
import en_core_sci_md
from tqdm import tqdm
import os, glob

# %%
from scipy.sparse import load_npz
from scispacy.umls_utils import UmlsKnowledgeBase
kb = UmlsKnowledgeBase()
st = kb.semantic_type_tree
# Out:
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/kbs/2020-10-09/umls_2020_aa_cat0129.jsonl not found in cache, downloading to /tmp/tmpndoaya_a
# Finished download, copying /tmp/tmpndoaya_a to cache at /root/.scispacy/datasets/4d7fb8fcae1035d1e0a47d9072b43d5a628057d35497fbfb2499b4b7b2dd4dd7.05ec7eef12f336d4666da85b7fa69b9401883a7dd4244473f7b88b413ccbba03.umls_2020_aa_cat0129.jsonl
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/umls_semantic_type_tree.tsv not found in cache, downloading to /tmp/tmpdjk2vxpt
# Finished download, copying /tmp/tmpdjk2vxpt to cache at /root/.scispacy/datasets/21a1012c532c3a431d60895c509f5b4d45b0f8966c4178b892190a302b21836f.330707f4efe774134872b9f77f0e3208c1d30f50800b3b39a6b8ec21d9adf1b7.umls_semantic_type_tree.tsv

# %%
import spacy_transformers
import re
nlp = spacy.load("en_core_sci_md")
#text ="Penicillin-resistant strains of Staphylococcus aureus emerged shortly after the introduction of the antibiotic in the early 1940s. [...] They expressed a β-lactamase that hydrolysed the critical β-lactam bond and destroyed the drug's antibacterial activity. [...] Mechanism of action of and resistance to penicillin [...]. The aminoglycoside class of antibiotics consists of many different agents. In the United States, gentamicin, tobramycin, amikacin, plazomicin, streptomycin, neomycin, and paromomycin are approved by the US Food and Drug Administration (FDA) and are available for clinical use" 
#text = "Avian influenza ,HPAI H5N8, reported by UK and Croatia,  in seal, fox, and wild bird, to #OIE "
chemin_dossier_articles_spacy="/content/dossier_transcriptions2411"
folder_path = (chemin_dossier_articles_spacy)
for filename in tqdm(glob.glob(os.path.join(folder_path, '*.txt'))):
  text=open(filename,encoding="utf-8").read()
  open(filename,'a',encoding="utf-8").write(', "Thematic Entities": "')

  text=re.sub('\\ "','\"',text)
  text=re.sub('}\.','}',text)
  
  doc = nlp(text)
  #print(list(doc.sents))
  entity_spans = []
  for ent in doc.ents:
      # print(ent.label_, ent.text)
      entity_spans.append(ent.text)
      #print(ent)

  annotations = []
  for ent_id, entity_span in enumerate(entity_spans):
    try:
      cuis = kb.alias_to_cuis[entity_span]
      #print(cuis)
      for cui in cuis:
          umls_ent = kb.cui_to_entity[cui]
          cid = umls_ent.concept_id
          pname = umls_ent.canonical_name
          stycodes = [(stycode, st.get_canonical_name(stycode)) 
                      for stycode in umls_ent.types]
          for stycode, styname in stycodes:
            annotations.append((ent_id, entity_span, cid, pname, stycode, styname))
            #liste_entities=[]
            if((styname=="Disease or Syndrome") or (styname=="Sign or Symptom") or (styname=="Virus")):
              entity=entity_span,styname
              open(filename,'a',encoding="utf-8").write(str(entity))
              #print(entity)
              #print(type(entity))
              #liste_entities.append(entity)
              print(entity)
              #liste_entities.append(entity)
              #open(filename,'a',encoding="utf-8").write(str(entity))
              print("ok")
            #liste_entities.append(entity)
            #print(liste_entities)
            #liste_entities=set(liste_entities)
            #print(liste_entities)
                          
            #open(filename,'a',encoding="utf-8").write(entity) #les articles sont tagués par spacy et écrits à la fin des fichiers 
              
                #print(entity_span,styname)
      
    except:
      continue
      #print(entity_span,"Entity")
  print("ok2")
  open(filename,'a',encoding="utf-8").write('"},')
# Out:
#   2%|▏         | 2/99 [00:00<00:13,  7.21it/s]
# ('Flu', 'Disease or Syndrome')
# ok
# ok2
# ('Flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ok2
#   3%|▎         | 3/99 [00:00<00:21,  4.48it/s]
# ('Flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
# ok2
#   5%|▌         | 5/99 [00:00<00:16,  5.86it/s]
# ('Influenzas', 'Disease or Syndrome')
# ok
# ('illness', 'Sign or Symptom')
# ok
# ('influenzas', 'Disease or Syndrome')
# ok
# ('illness', 'Sign or Symptom')
# ok
# ('respiratory symptoms', 'Sign or Symptom')
# ok
# ('fever', 'Sign or Symptom')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('Swine flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('H7N9', 'Disease or Syndrome')
# ok
# ('Swine influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('fever', 'Sign or Symptom')
# ok
# ('runny nose', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('pneumonia', 'Disease or Syndrome')
# ok
# ('respiratory failure', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('Swine flu', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ok2
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ok2
# ('Influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('tuberculosis', 'Disease or Syndrome')
# ok
# ('brucellosis', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('plague', 'Disease or Syndrome')
# ok
# ('salmonellosis', 'Disease or Syndrome')
# ok
# ('rabies', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1 virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('H5N1 virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenzas', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('Viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('Viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('malaria', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('finding', 'Sign or Symptom')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('Viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('Viruses', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('bovine tuberculosis', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('coronaviruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('aspergillosis', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('Viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('Viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('catching', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1 virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1 virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1 virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('infectious disease', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('noroviruses', 'Virus')
# ok
#   7%|▋         | 7/99 [00:07<02:17,  1.49s/it]
# ('coronaviruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('hot spots', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('finding', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenzas', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ok2
#   8%|▊         | 8/99 [00:07<01:51,  1.22s/it]
# ('Flu', 'Disease or Syndrome')
# ok
# ok2
#   9%|▉         | 9/99 [00:07<01:29,  1.01it/s]
# ('Influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('cough fever', 'Sign or Symptom')
# ok
# ('aches', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ok2
#  11%|█         | 11/99 [00:08<00:54,  1.63it/s]
# ('Virus', 'Virus')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Virus', 'Virus')
# ok
# ('Virus', 'Virus')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('dehydration', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ok2
#  12%|█▏        | 12/99 [00:08<00:44,  1.96it/s]
# ('Flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ok2
# ('Bird Flu', 'Disease or Syndrome')
# ok
# ('Bird Flu', 'Disease or Syndrome')
# ok
# ok2
#  14%|█▍        | 14/99 [00:08<00:28,  2.94it/s]
# ('Flu', 'Disease or Syndrome')
# ok
# ('Virus', 'Virus')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Disease', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Symptoms', 'Sign or Symptom')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Disease', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Fever', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('Viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('bird flu virus', 'Virus')
# ok
# ('bird flu virus', 'Disease or Syndrome')
# ok
# ('abdominal pain', 'Sign or Symptom')
# ok
# ('diarrhea', 'Sign or Symptom')
# ok
# ('pneumonia', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
#  16%|█▌        | 16/99 [00:09<00:22,  3.76it/s]
# ('Influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
# ('Influenza', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('clinical findings', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('systemic disease', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('clinical findings', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('nasal discharge', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('cyanosis', 'Sign or Symptom')
# ok
# ('viruses', 'Virus')
# ok
# ('Influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('burning', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ok2
#  17%|█▋        | 17/99 [00:09<00:18,  4.47it/s]
# ('Bird Flu', 'Disease or Syndrome')
# ok
# ('Bird Flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ok2
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('respiratory tract infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('viral disease', 'Disease or Syndrome')
# ok
# ('fever cough', 'Sign or Symptom')
# ok
# ('pain', 'Sign or Symptom')
# ok
# ('respiratory distress', 'Sign or Symptom')
# ok
# ('pneumonia', 'Disease or Syndrome')
# ok
# ('conjunctivitis', 'Disease or Syndrome')
# ok
# ok2
# ('Influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viral infection', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('lupus', 'Disease or Syndrome')
# ok
# ('lupus', 'Disease or Syndrome')
# ok
# ('lupus', 'Disease or Syndrome')
# ok
# ('lupus', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('cross infection', 'Disease or Syndrome')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('weak', 'Sign or Symptom')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('Viruses', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('systemic disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('Viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
#  19%|█▉        | 19/99 [00:16<02:14,  1.68s/it]
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('clinical infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('Viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('Viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('Viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('finding', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('wasted', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('boils', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('finding', 'Sign or Symptom')
# ok
# ('finding', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('piles', 'Disease or Syndrome')
# ok
# ('piles', 'Disease or Syndrome')
# ok
# ('piles', 'Disease or Syndrome')
# ok
# ('pile', 'Disease or Syndrome')
# ok
# ('pile', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ok2
#  20%|██        | 20/99 [00:16<01:46,  1.35s/it]
# ('Virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('Viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
# ('Flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('avian flu virus', 'Virus')
# ok
# ('avian flu virus', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('bird flu virus', 'Virus')
# ok
# ('bird flu virus', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('avian virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('condition', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu virus', 'Virus')
# ok
# ('bird flu virus', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('struck', 'Disease or Syndrome')
# ok
# ('bird flu virus', 'Virus')
# ok
# ('bird flu virus', 'Disease or Syndrome')
# ok
# ('condition', 'Disease or Syndrome')
# ok
# ('infectious diseases', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('ill', 'Sign or Symptom')
# ok
# ('fever', 'Sign or Symptom')
# ok
# ('weak', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('illnesses', 'Sign or Symptom')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('avian flu virus', 'Virus')
# ok
# ('avian flu virus', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('bird flu virus', 'Virus')
# ok
# ('bird flu virus', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('bird flu virus', 'Virus')
# ok
# ('bird flu virus', 'Disease or Syndrome')
# ok
# ('human virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('lung disease', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('feverish', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('ill', 'Sign or Symptom')
# ok
# ('sneezing', 'Sign or Symptom')
# ok
# ('coughing', 'Sign or Symptom')
# ok
# ('ill', 'Sign or Symptom')
# ok
# ('fever', 'Sign or Symptom')
# ok
# ('aches', 'Sign or Symptom')
# ok
# ('feeling dizzy', 'Sign or Symptom')
# ok
# ('lightheaded', 'Sign or Symptom')
# ok
# ('coughing', 'Sign or Symptom')
# ok
# ('pneumonia', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
#  21%|██        | 21/99 [00:18<01:54,  1.46s/it]
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('ill', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('H5N1 virus', 'Virus')
# ok
# ('condition', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
#  22%|██▏       | 22/99 [00:18<01:27,  1.13s/it]
# ('Flu', 'Disease or Syndrome')
# ok
# ('coronavirus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('H5N1 virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('coronavirus', 'Virus')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H7N9', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('coronavirus', 'Virus')
# ok
# ('cold', 'Disease or Syndrome')
# ok
# ('pneumonia', 'Disease or Syndrome')
# ok
# ('sore throat', 'Disease or Syndrome')
# ok
# ('sore throat', 'Sign or Symptom')
# ok
# ('symptom', 'Sign or Symptom')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('coronavirus', 'Virus')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('illness', 'Sign or Symptom')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('aches', 'Sign or Symptom')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('pneumonia', 'Disease or Syndrome')
# ok
# ('acute respiratory distress', 'Disease or Syndrome')
# ok
# ('catching', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
#  23%|██▎       | 23/99 [00:18<01:06,  1.15it/s]
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
# ('Flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('wasting', 'Disease or Syndrome')
# ok
# ok2
#  25%|██▌       | 25/99 [00:21<01:25,  1.16s/it]
# ('Influenza', 'Disease or Syndrome')
# ok
# ('Influenza', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('pest', 'Disease or Syndrome')
# ok
# ('founders', 'Disease or Syndrome')
# ok
# ('mouth disease', 'Disease or Syndrome')
# ok
# ('animal disease', 'Disease or Syndrome')
# ok
# ('pest', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('pest', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('finding', 'Sign or Symptom')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('Newcastle disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('mouth disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('animal disease', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('founders', 'Disease or Syndrome')
# ok
# ('gas', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('gas', 'Sign or Symptom')
# ok
# ('gas', 'Sign or Symptom')
# ok
# ('gas', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('gas', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('pain', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('animal disease', 'Disease or Syndrome')
# ok
# ('animal disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('animal diseases', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('exhausted', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
#  28%|██▊       | 28/99 [00:22<00:44,  1.60it/s]
# ('Avian Flu', 'Disease or Syndrome')
# ok
# ('Avian Flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ok2
# ('Flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ok2
# ('H1N1 influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('avian flu virus', 'Virus')
# ok
# ('avian flu virus', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('Viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ok2
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('FAC', 'Disease or Syndrome')
# ok
# ok2
#  31%|███▏      | 31/99 [00:22<00:26,  2.56it/s]
# ('Avian flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('cold', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ok2
# ('Influenza', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
#  32%|███▏      | 32/99 [00:23<00:21,  3.05it/s]
# ('Flu', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ok2
# ('Flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ok2
#  34%|███▍      | 34/99 [00:23<00:21,  3.02it/s]
# ('Flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('quality of life', 'Sign or Symptom')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ok2
# ('Influenza', 'Disease or Syndrome')
# ok
# ('Bird flu', 'Disease or Syndrome')
# ok
# ('Coronavirus', 'Virus')
# ok
# ('COVID-19', 'Disease or Syndrome')
# ok
# ('Pneumonia', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
#  35%|███▌      | 35/99 [00:24<00:19,  3.27it/s]
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('shaking', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('Ache', 'Sign or Symptom')
# ok
# ('abdominal pain', 'Sign or Symptom')
# ok
# ('vomiting', 'Sign or Symptom')
# ok
# ('pneumonia', 'Disease or Syndrome')
# ok
# ('respiratory failure', 'Disease or Syndrome')
# ok
# ('neurological symptoms', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('symptom', 'Sign or Symptom')
# ok
# ('symptom', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('illness', 'Sign or Symptom')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('Pneumonia', 'Disease or Syndrome')
# ok
# ok2
# ('Flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('histoplasmosis', 'Disease or Syndrome')
# ok
# ('fungal infection', 'Disease or Syndrome')
# ok
# ('giardia', 'Disease or Syndrome')
# ok
# ('gastrointestinal distress', 'Sign or Symptom')
# ok
# ('communicable infectious disease', 'Disease or Syndrome')
# ok
# ('chronic wasting disease', 'Disease or Syndrome')
# ok
# ('mad cow disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('Viruses', 'Virus')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('sneeze', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('coughing', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('fever', 'Sign or Symptom')
# ok
# ('symptom', 'Sign or Symptom')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('fever', 'Sign or Symptom')
# ok
# ('loss of appetite', 'Disease or Syndrome')
# ok
# ('Ache', 'Sign or Symptom')
# ok
# ('dry cough', 'Sign or Symptom')
# ok
# ('sore throat', 'Disease or Syndrome')
# ok
# ('sore throat', 'Sign or Symptom')
# ok
# ('stomach flu', 'Disease or Syndrome')
# ok
# ('stomach flu', 'Disease or Syndrome')
# ok
# ('stomach flu', 'Disease or Syndrome')
# ok
# ('stomach flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('gastrointestinal disease', 'Disease or Syndrome')
# ok
# ('respiratory disease', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('acute infection', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('ill', 'Sign or Symptom')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('pain', 'Sign or Symptom')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('illness', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('bacterial infections', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('avian virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viral pneumonia', 'Disease or Syndrome')
# ok
# ('diarrhea', 'Sign or Symptom')
# ok
# ('encephalitis', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ...
# ok
# ('virus', 'Virus')
# ok
# ('finding', 'Sign or Symptom')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('nervous', 'Sign or Symptom')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('Swine influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('fever', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('illness', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('hot spots', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('ha', 'Sign or Symptom')
# ok
# ('finding', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('spots', 'Sign or Symptom')
# ok
# ('spots', 'Sign or Symptom')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('hot spots', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('Swine influenza virus', 'Virus')
# ok
# ('swine influenza', 'Disease or Syndrome')
# ok
# ('human virus', 'Virus')
# ok
# ('ha', 'Sign or Symptom')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('blackout', 'Sign or Symptom')
# ok
# ('finding', 'Sign or Symptom')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('exhausted', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('respiratory disease', 'Disease or Syndrome')
# ok
# ('dengue', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('conjunctivitis', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
#  78%|███████▊  | 77/99 [00:47<00:20,  1.06it/s]
# ('bird flu', 'Disease or Syndrome')
# ok
# ('Influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('Influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('coronavirus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('Swine flu', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('infectious disease', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('coronavirus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('spells', 'Sign or Symptom')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
#  80%|███████▉  | 79/99 [00:47<00:11,  1.69it/s]
# ('Coronavirus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ok2
# ('Flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ok2
#  81%|████████  | 80/99 [00:48<00:12,  1.55it/s]
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('wind', 'Sign or Symptom')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ok2
#  82%|████████▏ | 81/99 [00:48<00:11,  1.55it/s]
# ('Flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenzas', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('cold', 'Disease or Syndrome')
# ok
# ('sneezing', 'Sign or Symptom')
# ok
# ('cold symptoms', 'Disease or Syndrome')
# ok
# ('sneeze', 'Sign or Symptom')
# ok
# ('sneezing', 'Sign or Symptom')
# ok
# ('cold symptoms', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ok2
# ('bird flu', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('Wuhan virus', 'Virus')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
#  84%|████████▍ | 83/99 [00:49<00:06,  2.51it/s]
# ('flu', 'Disease or Syndrome')
# ok
# ok2
# ('Influenza', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ('Flu', 'Disease or Syndrome')
# ok
# ok2
#  85%|████████▍ | 84/99 [00:49<00:04,  3.03it/s]
# ('Influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ok2
#  86%|████████▌ | 85/99 [00:49<00:04,  3.30it/s]
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
#  88%|████████▊ | 87/99 [00:49<00:02,  4.45it/s]
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('swine influenza', 'Disease or Syndrome')
# ok
# ok2
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ok2
#  89%|████████▉ | 88/99 [00:51<00:05,  1.96it/s]
# ('diseases', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('systemic infection', 'Disease or Syndrome')
# ok
# ('aids', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('cyanosis', 'Sign or Symptom')
# ok
# ('Ataxia', 'Sign or Symptom')
# ok
# ('Ataxia', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('Viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H7N9', 'Disease or Syndrome')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('spotty', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ok2
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
#  91%|█████████ | 90/99 [00:51<00:02,  3.00it/s]
# ('viruses', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
# ('flu', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('Influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('viruses', 'Virus')
# ok
# ('diarrhea', 'Sign or Symptom')
# ok
# ('Viruses', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('staring', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ok2
#  93%|█████████▎| 92/99 [00:51<00:01,  4.42it/s]
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ok2
# ('Influenza', 'Disease or Syndrome')
# ok
# ('Influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ok2
#  94%|█████████▍| 93/99 [00:51<00:01,  4.92it/s]
# ('avian flu virus', 'Virus')
# ok
# ('avian flu virus', 'Disease or Syndrome')
# ok
# ('avian flu virus', 'Virus')
# ok
# ('avian flu virus', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ok2
#  95%|█████████▍| 94/99 [00:52<00:01,  3.55it/s]
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viral infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viral disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('infection', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('diseases', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ok2
#  97%|█████████▋| 96/99 [00:52<00:00,  4.42it/s]
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ok2
# ('coronavirus', 'Virus')
# ok
# ('Coronavirus', 'Virus')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('bird flu', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('virus', 'Virus')
# ok
# ('coronavirus', 'Virus')
# ok
# ok2
#  99%|█████████▉| 98/99 [00:52<00:00,  5.52it/s]
# ('Influenza', 'Disease or Syndrome')
# ok
# ('Influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('flu', 'Disease or Syndrome')
# ok
# ('H5N1', 'Disease or Syndrome')
# ok
# ok2
# ('Influenza', 'Disease or Syndrome')
# ok
# ('influenza', 'Disease or Syndrome')
# ok
# ('viruses', 'Virus')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ('catch', 'Sign or Symptom')
# ok
# ok2
# 100%|██████████| 99/99 [00:52<00:00,  1.87it/s]
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ('disease', 'Disease or Syndrome')
# ok
# ok2

# %%
import re
for filename in tqdm(glob.glob(os.path.join(folder_path, '*.txt'))):
  text=open(filename,encoding="utf-8").read()
  text=re.sub('\\ "','\"',text)
  text=re.sub('}.','}',text)
  open(filename,'w',encoding="utf-8").write(text)
# Out:
# 100%|██████████| 99/99 [00:00<00:00, 2910.06it/s]

# %%
"""annotations = []
for ent_id, entity_span in enumerate(entity_spans):
  try:
    cuis = kb.alias_to_cuis[entity_span]
    #print(cuis)
    for cui in cuis:
        umls_ent = kb.cui_to_entity[cui]
        cid = umls_ent.concept_id
        pname = umls_ent.canonical_name
        stycodes = [(stycode, st.get_canonical_name(stycode)) 
                    for stycode in umls_ent.types]
        for stycode, styname in stycodes:
            annotations.append((ent_id, entity_span, 
                                cid, pname, 
                                stycode, styname))
            if((styname=="Disease or Syndrome") or (styname=="Sign or Symptom") or (styname=="Virus")):
                        entity=entity_span,styname
                        print(entity)
                        #print(type(entity))
                        #liste_entities.append(entity)
                        #print(liste_entities)
                        
            open(filename,'a',encoding="utf-8").write(str(entity)) #les articles sont tagués par spacy et écrits à la fin des fichiers 
          
            print(entity_span,styname)
  except:
    print(entity_span,"Entity")"""
# Out:
# 'annotations = []\nfor ent_id, entity_span in enumerate(entity_spans):\n  try:\n    cuis = kb.alias_to_cuis[entity_span]\n    #print(cuis)\n    for cui in cuis:\n        umls_ent = kb.cui_to_entity[cui]\n        cid = umls_ent.concept_id\n        pname = umls_ent.canonical_name\n        stycodes = [(stycode, st.get_canonical_name(stycode)) \n                    for stycode in umls_ent.types]\n        for stycode, styname in stycodes:\n            annotations.append((ent_id, entity_span, \n                                cid, pname, \n                                stycode, styname))\n            if((styname=="Disease or Syndrome") or (styname=="Sign or Symptom") or (styname=="Virus")):\n                        entity=entity_span,styname\n                        print(entity)\n                        #print(type(entity))\n                        #liste_entities.append(entity)\n                        #print(liste_entities)\n                        \n            open(filename,\'a\',encoding="utf-8").write(str(entity)) #les articles sont tagués par spacy et écrits à la fin des fichiers \n          \n            print(entity_span,styname)\n  except:\n    print(entity_span,"Entity")'
